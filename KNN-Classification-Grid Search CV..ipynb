# %%
#importing the Libraries#
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the Dataset#
dataset=pd.read_csv('Social_Network_Ads.csv')

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#create dummy data set. #drop a column#
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
#catogorical data convert to numerical data#
dataset=dataset.astype(int)

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
#show all columns in dataset#
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
#independent variable means input.  #split input variables. #dataset assigned to independent variable#
independent=dataset[['Age', 'EstimatedSalary','Gender_Male']]

# %%
#what saved in this file#
independent
# Out:
#      Age  EstimatedSalary  Gender_Male
# 0     19            19000            1
# 1     35            20000            1
# 2     26            43000            0
# 3     27            57000            0
# 4     19            76000            1
# ..   ...              ...          ...
# 395   46            41000            0
# 396   51            23000            1
# 397   50            20000            0
# 398   36            33000            1
# 399   49            36000            0
#
# [400 rows x 3 columns]

# %%
#dependent variable means output.  #split output variables. #dataset assigned to dependent variable#
dependent=dataset[['Purchased']]

# %%
#what saved in this file#
dependent
# Out:
#      Purchased
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 395          1
# 396          1
# 397          1
# 398          0
# 399          1
#
# [400 rows x 1 columns]

# %%
#machine learning algorithms provider is sklearn #split train set and test set#
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test=train_test_split(independent, dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Model creation#
from sklearn.model_selection    import GridSearchCV
from sklearn.neighbors    import KNeighborsClassifier
param_grid = {
    'n_neighbors': [3, 5, 7, 9],          # Number of neighbors
    'weights': ['uniform', 'distance'],   # Weight function used in prediction
    'metric': ['euclidean', 'manhattan', 'minkowski'],  # Distance metric
    'p': [1, 2]  # Power parameter for Minkowski (1 = Manhattan, 2 = Euclidean)
}
grid=GridSearchCV(KNeighborsClassifier(), param_grid, refit=True, verbose=3,n_jobs=-1)

#fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# GridSearchCV(estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': [3, 5, 7, 9], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
y_pred = grid.predict(X_test) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)



# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, y_pred)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,y_pred,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'metric': 'euclidean', 'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}: 0.9171245421245421

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[73  6]
#  [ 4 37]]

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94        79
#            1       0.86      0.90      0.88        41
#
#     accuracy                           0.92       120
#    macro avg       0.90      0.91      0.91       120
# weighted avg       0.92      0.92      0.92       120

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9424205001543686

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_metric  \
# 0        0.017805      0.006970         0.024743    1.274133e-02    euclidean
# 1        0.009375      0.007655         0.006250    7.654772e-03    euclidean
# 2        0.011510      0.007804         0.018987    3.989948e-03    euclidean
# 3        0.003125      0.006250         0.012501    6.250596e-03    euclidean
# 4        0.003125      0.006250         0.021877    7.655746e-03    euclidean
# 5        0.003125      0.006250         0.012500    6.250143e-03    euclidean
# 6        0.006249      0.007654         0.015630    9.667454e-06    euclidean
# 7        0.012498      0.006249         0.003125    6.249619e-03    euclidean
# 8        0.006250      0.007655         0.018752    6.252218e-03    euclidean
# 14                 9       2       uniform
# 15                 9       2      distance
# 16                 3       1       uniform
# 17                 3       1      distance
# 18                 3       2       uniform
# 19                 3       2      distance
# 20                 5       1       uniform
# 21                 5       1      distance
# 22                 5       2       uniform
# 23                 5       2      distance
# 24                 7       1       uniform
# 25                 7       1      distance
# 26                 7       2       uniform
# 27                 7       2      distance
# 28                 9       1       uniform
# 29                 9       1      distance
# 30                 9       2       uniform
# 31                 9       2      distance
# 32                 3       1       uniform
# 33                 3       1      distance
# 34                 3       2       uniform
# 35                 3       2      distance
# 36                 5       1       uniform
# 37                 5       1      distance
# 38                 5       2       uniform
# 39                 5       2      distance
# 40                 7       1       uniform
# 41                 7       1      distance
# 42                 7       2       uniform
# 43                 7       2      distance
# 44                 9       1       uniform
# 45                 9       1      distance
# 46                 9       2       uniform
# 47                 9       2      distance
#
#                                                params  split0_test_score  \
# 0   {'metric': 'euclidean', 'n_neighbors': 3, 'p':...           0.892857
# 1   {'metric': 'euclidean', 'n_neighbors': 3, 'p':...           0.875000
# 2   {'metric': 'euclidean', 'n_neighbors': 3, 'p':...           0.892857
# 3   {'metric': 'euclidean', 'n_neighbors': 3, 'p':...           0.875000
# 4   {'metric': 'euclidean', 'n_neighbors': 5, 'p':...           0.875000
# 5   {'metric': 'euclidean', 'n_neighbors': 5, 'p':...           0.857143
# 6   {'metric': 'euclidean', 'n_neighbors': 5, 'p':...           0.875000
# 7   {'metric': 'euclidean', 'n_neighbors': 5, 'p':...           0.857143
# 8   {'metric': 'euclidean', 'n_neighbors': 7, 'p':...           0.875000
# 9   {'metric': 'euclidean', 'n_neighbors': 7, 'p':...           0.857143
# 10  {'metric': 'euclidean', 'n_neighbors': 7, 'p':...           0.875000
# 11  {'metric': 'euclidean', 'n_neighbors': 7, 'p':...           0.857143
# 12  {'metric': 'euclidean', 'n_neighbors': 9, 'p':...           0.857143
# 13  {'metric': 'euclidean', 'n_neighbors': 9, 'p':...           0.857143
# 14  {'metric': 'euclidean', 'n_neighbors': 9, 'p':...           0.857143
# 15  {'metric': 'euclidean', 'n_neighbors': 9, 'p':...           0.857143
# 16  {'metric': 'manhattan', 'n_neighbors': 3, 'p':...           0.892857
# 17  {'metric': 'manhattan', 'n_neighbors': 3, 'p':...           0.875000
# 18  {'metric': 'manhattan', 'n_neighbors': 3, 'p':...           0.892857
# 19  {'metric': 'manhattan', 'n_neighbors': 3, 'p':...           0.875000
# 20  {'metric': 'manhattan', 'n_neighbors': 5, 'p':...           0.857143
# 21  {'metric': 'manhattan', 'n_neighbors': 5, 'p':...           0.875000
# 22  {'metric': 'manhattan', 'n_neighbors': 5, 'p':...           0.857143
# 23  {'metric': 'manhattan', 'n_neighbors': 5, 'p':...           0.875000
# 24  {'metric': 'manhattan', 'n_neighbors': 7, 'p':...           0.857143
# 25  {'metric': 'manhattan', 'n_neighbors': 7, 'p':...           0.857143
# 31           0.857143           0.839286           0.928571
# 32           0.839286           0.839286           0.910714
# 33           0.839286           0.803571           0.892857
# 34           0.875000           0.839286           0.910714
# 35           0.875000           0.821429           0.892857
# 36           0.875000           0.857143           0.946429
# 37           0.875000           0.821429           0.892857
# 38           0.875000           0.875000           0.928571
# 39           0.857143           0.857143           0.928571
# 40           0.857143           0.857143           0.946429
# 41           0.857143           0.821429           0.910714
# 42           0.875000           0.857143           0.946429
# 43           0.875000           0.857143           0.928571
# 44           0.875000           0.857143           0.946429
# 45           0.857143           0.839286           0.928571
# 46           0.875000           0.839286           0.946429
# 47           0.857143           0.857143           0.928571
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.910714         0.885714        0.026726               28
# 1            0.892857         0.871429        0.026245               43
# 2            0.910714         0.885714        0.026726               28
# 3            0.892857         0.871429        0.026245               43
# 4            0.946429         0.900000        0.031135                4
# 5            0.946429         0.889286        0.039770               22
# 6            0.946429         0.900000        0.031135                4
# 7            0.946429         0.889286        0.039770               22
# 8            0.964286         0.903571        0.043154                1
# 9            0.946429         0.892857        0.037457               19
# 10           0.964286         0.903571        0.043154                1
# 11           0.946429         0.892857        0.037457               19
# 12           0.964286         0.896429        0.049744               13
# 13           0.946429         0.889286        0.039770               22
# 14           0.964286         0.896429        0.049744               13
# 15           0.946429         0.889286        0.039770               22
# 16           0.910714         0.878571        0.032733               37
# 17           0.910714         0.864286        0.038465               46
# 18           0.910714         0.878571        0.032733               37
# 19           0.910714         0.864286        0.038465               46
# 20           0.964286         0.900000        0.046015                4
# 21           0.964286         0.885714        0.046015               31
# 22           0.964286         0.900000        0.046015                4
# 23           0.964286         0.885714        0.046015               31
# 24           0.964286         0.896429        0.048445               16
# 25           0.946429         0.878571        0.044320               40
# 26           0.964286         0.896429        0.048445               16
# 27           0.946429         0.878571        0.044320               40
# 28           0.964286         0.900000        0.046015                4
# 29           0.946429         0.885714        0.043154               31
# 30           0.964286         0.900000        0.046015                4
# 31           0.946429         0.885714        0.043154               31
# 32           0.910714         0.878571        0.032733               37
# 33           0.910714         0.864286        0.038465               46
# 34           0.910714         0.885714        0.026726               28
# 35           0.892857         0.871429        0.026245               43
# 36           0.964286         0.900000        0.046015                4
# 37           0.964286         0.885714        0.046015               31
# 38           0.946429         0.900000        0.031135                4
# 39           0.946429         0.889286        0.039770               22
# 40           0.964286         0.896429        0.048445               16
# 41           0.946429         0.878571        0.044320               40
# 42           0.964286         0.903571        0.043154                1
# 43           0.946429         0.892857        0.037457               19
# 44           0.964286         0.900000        0.046015                4
# 45           0.946429         0.885714        0.043154               31
# 46           0.964286         0.896429        0.049744               13
# 47           0.946429         0.889286        0.039770               22

# %%
age_input=float(input("Age."))
salary_input=float(input("salary:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
# Out:
# Age. 20
# salary: 55
# Sex Male 0 or 1: 1

# %%
grid.predict([[age_input,salary_input,sex_male_input]])
# Out:
# array([1])
