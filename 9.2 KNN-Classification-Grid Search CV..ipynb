# %%
#importing the Libraries#
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the Dataset#
dataset=pd.read_csv('Social_Network_Ads.csv')

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#create dummy data set. #drop a column#
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
#catogorical data convert to numerical data#
dataset=dataset.astype(int)

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
#show all columns in dataset#
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
#independent variable means input.  #split input variables. #dataset assigned to independent variable#
independent=dataset[['Age', 'EstimatedSalary','Gender_Male']]

# %%
#what saved in this file#
independent
# Out:
#      Age  EstimatedSalary  Gender_Male
# 0     19            19000            1
# 1     35            20000            1
# 2     26            43000            0
# 3     27            57000            0
# 4     19            76000            1
# ..   ...              ...          ...
# 395   46            41000            0
# 396   51            23000            1
# 397   50            20000            0
# 398   36            33000            1
# 399   49            36000            0
#
# [400 rows x 3 columns]

# %%
#dependent variable means output.  #split output variables. #dataset assigned to dependent variable#
dependent=dataset[['Purchased']]

# %%
#what saved in this file#
dependent
# Out:
#      Purchased
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 395          1
# 396          1
# 397          1
# 398          0
# 399          1
#
# [400 rows x 1 columns]

# %%
#machine learning algorithms provider is sklearn #split train set and test set#
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test=train_test_split(independent, dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Model creation#
from sklearn.model_selection    import GridSearchCV
from sklearn.neighbors    import KNeighborsClassifier
param_grid = {
    'n_neighbors': [3, 5, 7, 9],          # Number of neighbors
    'weights': ['uniform', 'distance'],   # Weight function used in prediction
    'metric': ['euclidean', 'manhattan', 'minkowski'],  # Distance metric
    'p': [1, 2]  # Power parameter for Minkowski (1 = Manhattan, 2 = Euclidean)
}
grid=GridSearchCV(KNeighborsClassifier(), param_grid, refit=True, verbose=3,n_jobs=-1,scoring='f1_weighted')

#fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# GridSearchCV(estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': [3, 5, 7, 9], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
y_pred = grid.predict(X_test) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)



# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, y_pred)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,y_pred,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'metric': 'euclidean', 'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}: 0.9171245421245421

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[73  6]
#  [ 4 37]]

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94        79
#            1       0.86      0.90      0.88        41
#
#     accuracy                           0.92       120
#    macro avg       0.90      0.91      0.91       120
# weighted avg       0.92      0.92      0.92       120

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9424205001543686

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_metric  \
# 0        0.006250  7.655181e-03         0.031253    8.662177e-07    euclidean
# 1        0.006250  7.655123e-03         0.018750    6.250763e-03    euclidean
# 2        0.009376  7.655240e-03         0.021877    7.655746e-03    euclidean
# 3        0.003125  6.250000e-03         0.015629    1.921601e-06    euclidean
# 4        0.006249  7.653487e-03         0.025003    7.653643e-03    euclidean
# 5        0.009374  7.653643e-03         0.015628    1.482036e-06    euclidean
# 6        0.006251  7.655356e-03         0.025002    7.654403e-03    euclidean
# 7        0.006250  7.655181e-03         0.018006    4.759741e-03    euclidean
# 8        0.004747  6.280401e-03         0.036895    6.976962e-03    euclidean
# 9        0.009375  7.654578e-03         0.018753    6.251860e-03    euclidean
# 10       0.003125  6.249332e-03         0.018752    6.250000e-03    euclidean
# 11       0.003125  6.250381e-03         0.015626    2.150530e-06    euclidean
# 12       0.000000  0.000000e+00         0.031253    1.081065e-06    euclidean
# 13       0.006250  7.655123e-03         0.015627    1.122341e-06    euclidean
# 14       0.009375  7.654617e-03         0.025002    7.654208e-03    euclidean
# 15       0.006250  7.655181e-03         0.015626    7.599534e-07    euclidean
# 16       0.006251  7.655765e-03         0.025002    7.655590e-03    manhattan
# 17       0.006250  7.654772e-03         0.015627    2.259826e-06    manhattan
# 18       0.009374  7.653994e-03         0.025003    7.653896e-03    manhattan
# 19       0.015625  1.711624e-02         0.018751    6.251168e-03    manhattan
# 20       0.000000  0.000000e+00         0.033965    5.423284e-03    manhattan
# 21       0.005565  6.901191e-03         0.020848    5.706951e-03    manhattan
# 22       0.007198  7.097220e-03         0.018896    6.183901e-03    manhattan
# 23       0.006250  7.655181e-03         0.015628    2.279860e-06    manhattan
# 24       0.006250  7.655181e-03         0.028127    6.250215e-03    manhattan
# 25       0.003125  6.250381e-03         0.015626    9.122432e-07    manhattan
# 26       0.006250  7.655181e-03         0.031252    4.156970e-07    manhattan
# 27       0.006250  7.654772e-03         0.015626    8.064048e-07    manhattan
# 28       0.000000  0.000000e+00         0.031252    1.210077e-06    manhattan
# 29       0.003125  6.249905e-03         0.015626    9.172146e-07    manhattan
# 30       0.003126  6.251144e-03         0.031252    1.148376e-06    manhattan
# 31       0.003126  6.251717e-03         0.018751    6.251049e-03    manhattan
# 32       0.003125  6.249905e-03         0.028127    6.249571e-03    minkowski
# 33       0.006250  7.654247e-03         0.015627    1.755901e-06    minkowski
# 34       0.004798  6.310219e-03         0.029157    6.511759e-03    minkowski
# 35       0.003182  6.225462e-03         0.019779    8.620185e-03    minkowski
# 36       0.000000  0.000000e+00         0.031252    2.132481e-07    minkowski
# 37       0.006250  7.655006e-03         0.018751    6.250143e-03    minkowski
# 38       0.000000  0.000000e+00         0.031253    9.584308e-07    minkowski
# 39       0.003125  6.249714e-03         0.018752    6.250119e-03    minkowski
# 40       0.015625  6.289914e-07         0.018752    6.250715e-03    minkowski
# 41       0.003126  6.252003e-03         0.018751    6.250191e-03    minkowski
# 42       0.015625  2.323328e-06         0.015627    2.445389e-06    minkowski
# 43       0.006249  7.653896e-03         0.018753    6.252075e-03    minkowski
# 44       0.006249  7.653429e-03         0.025003    7.653507e-03    minkowski
# 45       0.009375  7.654889e-03         0.018751    6.249619e-03    minkowski
# 46       0.006250  7.654247e-03         0.025003    7.654733e-03    minkowski
# 47       0.006250  7.654889e-03         0.021877    7.655317e-03    minkowski
#
#    param_n_neighbors param_p param_weights  \
# 0                  3       1       uniform
# 1                  3       1      distance
# 2                  3       2       uniform
# 3                  3       2      distance
# 4                  5       1       uniform
# 5                  5       1      distance
# 6                  5       2       uniform
# 7                  5       2      distance
# 8                  7       1       uniform
# 9                  7       1      distance
# 10                 7       2       uniform
# 11                 7       2      distance
# 12                 9       1       uniform
# 13                 9       1      distance
# 14                 9       2       uniform
# 15                 9       2      distance
# 16                 3       1       uniform
# 17                 3       1      distance
# 18                 3       2       uniform
# 19                 3       2      distance
# 20                 5       1       uniform
# 21                 5       1      distance
# 22                 5       2       uniform
# 23                 5       2      distance
# 24                 7       1       uniform
# 25                 7       1      distance
# 26                 7       2       uniform
# 27                 7       2      distance
# 28                 9       1       uniform
# 29                 9       1      distance
# 30                 9       2       uniform
# 31                 9       2      distance
# 32                 3       1       uniform
# 33                 3       1      distance
# 34                 3       2       uniform
# 35                 3       2      distance
# 36                 5       1       uniform
# 37                 5       1      distance
# 38                 5       2       uniform
# 39                 5       2      distance
# 40                 7       1       uniform
# 41                 7       1      distance
# 42                 7       2       uniform
# 43                 7       2      distance
# 44                 9       1       uniform
# 45                 9       1      distance
# 46                 9       2       uniform
# 47                 9       2      distance
#
#                                                params  split0_test_score  \
# 0   {'metric': 'euclidean', 'n_neighbors': 3, 'p':...           0.892857
# 1   {'metric': 'euclidean', 'n_neighbors': 3, 'p':...           0.874254
# 2   {'metric': 'euclidean', 'n_neighbors': 3, 'p':...           0.892857
# 3   {'metric': 'euclidean', 'n_neighbors': 3, 'p':...           0.874254
# 4   {'metric': 'euclidean', 'n_neighbors': 5, 'p':...           0.874254
# 5   {'metric': 'euclidean', 'n_neighbors': 5, 'p':...           0.855314
# 6   {'metric': 'euclidean', 'n_neighbors': 5, 'p':...           0.874254
# 7   {'metric': 'euclidean', 'n_neighbors': 5, 'p':...           0.855314
# 8   {'metric': 'euclidean', 'n_neighbors': 7, 'p':...           0.874254
# 9   {'metric': 'euclidean', 'n_neighbors': 7, 'p':...           0.855314
# 10  {'metric': 'euclidean', 'n_neighbors': 7, 'p':...           0.874254
# 11  {'metric': 'euclidean', 'n_neighbors': 7, 'p':...           0.855314
# 12  {'metric': 'euclidean', 'n_neighbors': 9, 'p':...           0.855314
# 13  {'metric': 'euclidean', 'n_neighbors': 9, 'p':...           0.855314
# 14  {'metric': 'euclidean', 'n_neighbors': 9, 'p':...           0.855314
# 15  {'metric': 'euclidean', 'n_neighbors': 9, 'p':...           0.855314
# 16  {'metric': 'manhattan', 'n_neighbors': 3, 'p':...           0.892857
# 17  {'metric': 'manhattan', 'n_neighbors': 3, 'p':...           0.874254
# 18  {'metric': 'manhattan', 'n_neighbors': 3, 'p':...           0.892857
# 19  {'metric': 'manhattan', 'n_neighbors': 3, 'p':...           0.874254
# 20  {'metric': 'manhattan', 'n_neighbors': 5, 'p':...           0.855314
# 21  {'metric': 'manhattan', 'n_neighbors': 5, 'p':...           0.874254
# 22  {'metric': 'manhattan', 'n_neighbors': 5, 'p':...           0.855314
# 23  {'metric': 'manhattan', 'n_neighbors': 5, 'p':...           0.874254
# 24  {'metric': 'manhattan', 'n_neighbors': 7, 'p':...           0.855314
# 25  {'metric': 'manhattan', 'n_neighbors': 7, 'p':...           0.855314
# 26  {'metric': 'manhattan', 'n_neighbors': 7, 'p':...           0.855314
# 27  {'metric': 'manhattan', 'n_neighbors': 7, 'p':...           0.855314
# 28  {'metric': 'manhattan', 'n_neighbors': 9, 'p':...           0.855314
# 29  {'metric': 'manhattan', 'n_neighbors': 9, 'p':...           0.855314
# 30  {'metric': 'manhattan', 'n_neighbors': 9, 'p':...           0.855314
# 31  {'metric': 'manhattan', 'n_neighbors': 9, 'p':...           0.855314
# 32  {'metric': 'minkowski', 'n_neighbors': 3, 'p':...           0.892857
# 33  {'metric': 'minkowski', 'n_neighbors': 3, 'p':...           0.874254
# 34  {'metric': 'minkowski', 'n_neighbors': 3, 'p':...           0.892857
# 35  {'metric': 'minkowski', 'n_neighbors': 3, 'p':...           0.874254
# 36  {'metric': 'minkowski', 'n_neighbors': 5, 'p':...           0.855314
# 37  {'metric': 'minkowski', 'n_neighbors': 5, 'p':...           0.874254
# 38  {'metric': 'minkowski', 'n_neighbors': 5, 'p':...           0.874254
# 39  {'metric': 'minkowski', 'n_neighbors': 5, 'p':...           0.855314
# 40  {'metric': 'minkowski', 'n_neighbors': 7, 'p':...           0.855314
# 41  {'metric': 'minkowski', 'n_neighbors': 7, 'p':...           0.855314
# 42  {'metric': 'minkowski', 'n_neighbors': 7, 'p':...           0.874254
# 43  {'metric': 'minkowski', 'n_neighbors': 7, 'p':...           0.855314
# 44  {'metric': 'minkowski', 'n_neighbors': 9, 'p':...           0.855314
# 45  {'metric': 'minkowski', 'n_neighbors': 9, 'p':...           0.855314
# 46  {'metric': 'minkowski', 'n_neighbors': 9, 'p':...           0.855314
# 47  {'metric': 'minkowski', 'n_neighbors': 9, 'p':...           0.855314
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.874254           0.841398           0.911105
# 1            0.874254           0.824293           0.893717
# 2            0.874254           0.841398           0.911105
# 3            0.874254           0.824293           0.893717
# 4            0.874254           0.876643           0.929144
# 5            0.855314           0.859435           0.929144
# 6            0.874254           0.876643           0.929144
# 7            0.855314           0.859435           0.929144
# 8            0.874254           0.859435           0.947015
# 9            0.874254           0.859435           0.929144
# 10           0.874254           0.859435           0.947015
# 11           0.874254           0.859435           0.929144
# 12           0.874254           0.841398           0.946663
# 13           0.855314           0.859435           0.929144
# 14           0.874254           0.841398           0.946663
# 15           0.855314           0.859435           0.929144
# 16           0.835985           0.840114           0.911105
# 17           0.835985           0.806153           0.893717
# 18           0.835985           0.840114           0.911105
# 19           0.835985           0.806153           0.893717
# 20           0.874254           0.858503           0.946663
# 21           0.874254           0.824293           0.893717
# 22           0.874254           0.858503           0.946663
# 23           0.874254           0.824293           0.893717
# 24           0.855314           0.858503           0.947015
# 25           0.855314           0.824293           0.911105
# 26           0.855314           0.858503           0.947015
# 27           0.855314           0.824293           0.911105
# 28           0.874254           0.858503           0.946663
# 29           0.855314           0.841398           0.929144
# 30           0.874254           0.858503           0.946663
# 31           0.855314           0.841398           0.929144
# 32           0.835985           0.840114           0.911105
# 33           0.835985           0.806153           0.893717
# 34           0.874254           0.841398           0.911105
# 35           0.874254           0.824293           0.893717
# 36           0.874254           0.858503           0.946663
# 37           0.874254           0.824293           0.893717
# 38           0.874254           0.876643           0.929144
# 39           0.855314           0.859435           0.929144
# 40           0.855314           0.858503           0.947015
# 41           0.855314           0.824293           0.911105
# 42           0.874254           0.859435           0.947015
# 43           0.874254           0.859435           0.929144
# 44           0.874254           0.858503           0.946663
# 45           0.855314           0.841398           0.929144
# 46           0.874254           0.841398           0.946663
# 47           0.855314           0.859435           0.929144
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.910254         0.885974        0.026049               31
# 1            0.891667         0.871637        0.025075               43
# 2            0.910254         0.885974        0.026049               31
# 3            0.891667         0.871637        0.025075               43
# 4            0.946153         0.900089        0.031147                4
# 5            0.946153         0.889072        0.040054               22
# 6            0.946153         0.900089        0.031147                4
# 7            0.946153         0.889072        0.040054               22
# 8            0.964286         0.903849        0.042989                1
# 9            0.946153         0.892860        0.037496               19
# 10           0.964286         0.903849        0.042989                1
# 11           0.946153         0.892860        0.037496               19
# 12           0.964286         0.896383        0.049676               13
# 13           0.946153         0.889072        0.040054               22
# 14           0.964286         0.896383        0.049676               13
# 15           0.946153         0.889072        0.040054               22
# 16           0.911105         0.878233        0.033505               40
# 17           0.911105         0.864243        0.038309               46
# 18           0.911105         0.878233        0.033505               40
# 19           0.911105         0.864243        0.038309               46
# 20           0.964286         0.899804        0.046242                7
# 21           0.964286         0.886161        0.045325               28
# 22           0.964286         0.899804        0.046242                7
# 23           0.964286         0.886161        0.045325               28
# 24           0.964286         0.896086        0.048953               16
# 25           0.946153         0.878436        0.043940               37
# 26           0.964286         0.896086        0.048953               16
# 27           0.946153         0.878436        0.043940               37
# 28           0.964286         0.899804        0.046242                7
# 29           0.946153         0.885465        0.043246               34
# 30           0.964286         0.899804        0.046242                7
# 31           0.946153         0.885465        0.043246               34
# 32           0.911105         0.878233        0.033505               40
# 33           0.911105         0.864243        0.038309               46
# 34           0.910254         0.885974        0.026049               31
# 35           0.891667         0.871637        0.025075               43
# 36           0.964286         0.899804        0.046242                7
# 37           0.964286         0.886161        0.045325               28
# 38           0.946153         0.900089        0.031147                4
# 39           0.946153         0.889072        0.040054               22
# 40           0.964286         0.896086        0.048953               16
# 41           0.946153         0.878436        0.043940               37
# 42           0.964286         0.903849        0.042989                1
# 43           0.946153         0.892860        0.037496               19
# 44           0.964286         0.899804        0.046242                7
# 45           0.946153         0.885465        0.043246               34
# 46           0.964286         0.896383        0.049676               13
# 47           0.946153         0.889072        0.040054               22

# %%
age_input=float(input("Age."))
salary_input=float(input("salary:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
# Out:
# Age. 20
# salary: 55
# Sex Male 0 or 1: 1

# %%
grid.predict([[age_input,salary_input,sex_male_input]])
# Out:
# array([1])
