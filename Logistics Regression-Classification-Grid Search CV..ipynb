# %%
#importing the Libraries#
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the Dataset#
dataset=pd.read_csv('Social_Network_Ads.csv')

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#create dummy data set. #drop a column#
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
#catogorical data convert to numerical data#
dataset=dataset.astype(int)

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
#show all columns in dataset#
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
#independent variable means input.  #split input variables. #dataset assigned to independent variable#
independent=dataset[['Age', 'EstimatedSalary','Gender_Male']]

# %%
#what saved in this file#
independent
# Out:
#      Age  EstimatedSalary  Gender_Male
# 0     19            19000            1
# 1     35            20000            1
# 2     26            43000            0
# 3     27            57000            0
# 4     19            76000            1
# ..   ...              ...          ...
# 395   46            41000            0
# 396   51            23000            1
# 397   50            20000            0
# 398   36            33000            1
# 399   49            36000            0
#
# [400 rows x 3 columns]

# %%
#dependent variable means output.  #split output variables. #dataset assigned to dependent variable#
dependent=dataset[['Purchased']]

# %%
#what saved in this file#
dependent
# Out:
#      Purchased
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 395          1
# 396          1
# 397          1
# 398          0
# 399          1
#
# [400 rows x 1 columns]

# %%
#machine learning algorithms provider is sklearn #split train set and test set#
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test=train_test_split(independent, dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Model creation#
from sklearn.model_selection  import GridSearchCV
from sklearn.linear_model   import LogisticRegression
param_grid = {
    'penalty': ['l1', 'l2', 'elasticnet', 'none'],  # Regularization type
    'C': [0.01, 0.1, 1, 10, 100],  # Inverse of regularization strength
    'solver': ['liblinear', 'saga'],  # Solvers that support l1 and elasticnet
    'max_iter': [100, 200, 500],  # Maximum number of iterations
    'l1_ratio': [0.1, 0.5, 0.9]  # Only used for 'elasticnet' penalty
}
grid=GridSearchCV(LogisticRegression(), param_grid, refit=True, verbose=3,n_jobs=-1,scoring='f1_weighted')

#fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 360 candidates, totalling 1800 fits
# C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 450 fits failed out of a total of 1800.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 225 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 64, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 225 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 71, in _check_solver
#     raise ValueError("penalty='none' is not supported for the liblinear solver")
# ValueError: penalty='none' is not supported for the liblinear solver
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.49417105 0.49417105 0.80591978 0.69875295        nan 0.65578912
#         nan 0.82017479 0.49417105 0.49417105 0.80591978 0.69875295
#         nan 0.65578912        nan 0.82017479 0.49417105 0.49417105
#  0.80591978 0.69875295        nan 0.65578912        nan 0.82017479
#  0.49417105 0.49417105 0.80591978 0.69875295        nan 0.49417105
#         nan 0.82017479 0.49417105 0.49417105 0.80591978 0.69875295
#         nan 0.49417105        nan 0.82017479 0.49417105 0.49417105
#  0.80591978 0.69875295        nan 0.49417105        nan 0.823975
#  0.49417105 0.49417105 0.80591978 0.69875295        nan 0.49417105
#         nan 0.82017479 0.49417105 0.49417105 0.80591978 0.69875295
#         nan 0.49417105        nan 0.82017479 0.49417105 0.49417105
#  0.80591978 0.69875295        nan 0.49417105        nan 0.82017479
#  0.83576261 0.81047569 0.82413212 0.80350025        nan 0.80259931
#         nan 0.82017479 0.83576261 0.81047569 0.82413212 0.80350025
#         nan 0.80259931        nan 0.82017479 0.83576261 0.81047569
 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}: 0.8993749999999998

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[74  5]
#  [ 7 34]]

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92        79
#            1       0.87      0.83      0.85        41
#
#     accuracy                           0.90       120
#    macro avg       0.89      0.88      0.89       120
# weighted avg       0.90      0.90      0.90       120

# %%
#roc_auc = receiver operatic charateristics_area under curve_score
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9465884532263044

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0         0.009376      0.007655         0.021879        0.007654    0.01
# 1         0.012502      0.006251         0.015628        0.000002    0.01
# 2         0.019459      0.005057         0.015555        0.000668    0.01
# 3         0.012498      0.006249         0.025005        0.012499    0.01
# 4         0.003125      0.006250         0.000000        0.000000    0.01
# ..             ...           ...              ...             ...     ...
# 355       0.006388      0.005886         0.019405        0.007698     100
# 356       0.000000      0.000000         0.000000        0.000000     100
# 357       0.010351      0.006372         0.016797        0.002082     100
# 358       0.000000      0.000000         0.000000        0.000000     100
# 359       0.012501      0.006251         0.015627        0.000002     100
#
#     param_l1_ratio param_max_iter param_penalty param_solver  \
# 0              0.1            100            l1    liblinear
# 1              0.1            100            l1         saga
# 2              0.1            100            l2    liblinear
# 3              0.1            100            l2         saga
# 4              0.1            100    elasticnet    liblinear
# ..             ...            ...           ...          ...
# 355            0.9            500            l2         saga
# 356            0.9            500    elasticnet    liblinear
# 357            0.9            500    elasticnet         saga
# 358            0.9            500          none    liblinear
# 359            0.9            500          none         saga
#
#                                                 params  split0_test_score  \
# 0    {'C': 0.01, 'l1_ratio': 0.1, 'max_iter': 100, ...           0.503106
# 1    {'C': 0.01, 'l1_ratio': 0.1, 'max_iter': 100, ...           0.503106
# 2    {'C': 0.01, 'l1_ratio': 0.1, 'max_iter': 100, ...           0.795918
# 3    {'C': 0.01, 'l1_ratio': 0.1, 'max_iter': 100, ...           0.755102
# 4    {'C': 0.01, 'l1_ratio': 0.1, 'max_iter': 100, ...                NaN
# ..                                                 ...                ...
# 355  {'C': 100, 'l1_ratio': 0.9, 'max_iter': 500, '...           0.835985
# 356  {'C': 100, 'l1_ratio': 0.9, 'max_iter': 500, '...                NaN
# 357  {'C': 100, 'l1_ratio': 0.9, 'max_iter': 500, '...           0.835985
# 358  {'C': 100, 'l1_ratio': 0.9, 'max_iter': 500, '...                NaN
# 359  {'C': 100, 'l1_ratio': 0.9, 'max_iter': 500, '...           0.835985
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             0.503106           0.503106           0.480769
# 1             0.503106           0.503106           0.480769
# 2             0.763089           0.616071           0.927778
# 3             0.673469           0.618196           0.765625
# 4                  NaN                NaN                NaN
# ..                 ...                ...                ...
# 355           0.802399           0.644599           0.927778
# 356                NaN                NaN                NaN
# 357           0.802399           0.644599           0.927778
# 358                NaN                NaN                NaN
# 359           0.802399           0.644599           0.927778
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.480769         0.494171        0.010943              247
# 1             0.480769         0.494171        0.010943              247
# 2             0.926743         0.805920        0.116124              211
# 3             0.681373         0.698753        0.054914              235
# 4                  NaN              NaN             NaN              271
# ..                 ...              ...             ...              ...
# 355           0.890114         0.820175        0.097839               50
# 356                NaN              NaN             NaN              271
# 357           0.890114         0.820175        0.097839               50
# 358                NaN              NaN             NaN              271
# 359           0.890114         0.820175        0.097839               50
#
# [360 rows x 18 columns]

# %%
age_input=float(input("Age."))
salary_input=float(input("salary:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
# Out:
# Age. 20
# salary: 55
# Sex Male 0 or 1: 1

# %%
grid.predict([[age_input,salary_input,sex_male_input]])
# Out:
# array([1])
