# %%
#importing the libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#50_Startups.csv file  assigned to dataset#
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#create dummy data set. #drop a column#
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
#catogorical data convert to numerical data# 
dataset=dataset.astype(int)

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
#show all columns in dataset#
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
#independent variable means input.  #split input variables. #dataset assigned to independent variable#
independent=dataset[['Age', 'EstimatedSalary','Gender_Male']]

# %%
#what saved in this file#
independent
# Out:
#      Age  EstimatedSalary  Gender_Male
# 0     19            19000            1
# 1     35            20000            1
# 2     26            43000            0
# 3     27            57000            0
# 4     19            76000            1
# ..   ...              ...          ...
# 395   46            41000            0
# 396   51            23000            1
# 397   50            20000            0
# 398   36            33000            1
# 399   49            36000            0
#
# [400 rows x 3 columns]

# %%
#dependent variable means output.  #split output variables. #dataset assigned to dependent variable#
dependent=dataset[['Purchased']]

# %%
#what saved in this file#
dependent
# Out:
#      Purchased
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 395          1
# 396          1
# 397          1
# 398          0
# 399          1
#
# [400 rows x 1 columns]

# %%
#machine learning algorithms provider is sklearn #split train set and test set#
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test=train_test_split(independent, dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Model creation#
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble  import RandomForestClassifier
param_grid = {
    'n_estimators': [100, 200, 500],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    'bootstrap': [True, False]}
    
grid=GridSearchCV(RandomForestClassifier(), param_grid, refit=True, verbose=3,n_jobs=-1,scoring='f1_weighted')

#fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# GridSearchCV(estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [10, 20, None],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 500]},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
y_pred = grid.predict(X_test) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)



# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, y_pred)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,y_pred,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'bootstrap': True, 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 500}: 0.9090638836179633

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[72  7]
#  [ 4 37]]

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        79
#            1       0.84      0.90      0.87        41
#
#     accuracy                           0.91       120
#    macro avg       0.89      0.91      0.90       120
# weighted avg       0.91      0.91      0.91       120

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9712874343933313

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.604339      0.089896         0.053716        0.017695
# 1         0.799914      0.060836         0.051649        0.006293
# 2         2.257215      0.075783         0.143761        0.006250
# 3         0.463544      0.011567         0.043754        0.006251
# 4         0.862988      0.013450         0.071881        0.007656
# ..             ...           ...              ...             ...
# 481       0.676897      0.007326         0.073009        0.009191
# 482       1.762027      0.058449         0.156182        0.003013
# 483       0.345893      0.002382         0.045968        0.015470
# 484       0.657725      0.010399         0.065629        0.006250
# 485       1.699226      0.033473         0.140527        0.017117
#
#     param_bootstrap param_max_depth param_max_features param_min_samples_leaf  \
# 0              True              10               auto                      1
# 1              True              10               auto                      1
# 2              True              10               auto                      1
# 3              True              10               auto                      1
# 4              True              10               auto                      1
# ..              ...             ...                ...                    ...
# 481           False            None               log2                      4
# 482           False            None               log2                      4
# 483           False            None               log2                      4
# 484           False            None               log2                      4
# 485           False            None               log2                      4
#
#     param_min_samples_split param_n_estimators  \
# 0                         2                100
# 1                         2                200
# 2                         2                500
# 3                         5                100
# 4                         5                200
# ..                      ...                ...
# 481                       5                200
# 482                       5                500
# 483                      10                100
# 484                      10                200
# 485                      10                500
#
#                                                 params  split0_test_score  \
# 0    {'bootstrap': True, 'max_depth': 10, 'max_feat...           0.874254
# 1    {'bootstrap': True, 'max_depth': 10, 'max_feat...           0.874254
# 2    {'bootstrap': True, 'max_depth': 10, 'max_feat...           0.874254
# 3    {'bootstrap': True, 'max_depth': 10, 'max_feat...           0.874254
# 4    {'bootstrap': True, 'max_depth': 10, 'max_feat...           0.874254
# ..                                                 ...                ...
# 481  {'bootstrap': False, 'max_depth': None, 'max_f...           0.874254
# 482  {'bootstrap': False, 'max_depth': None, 'max_f...           0.874254
# 483  {'bootstrap': False, 'max_depth': None, 'max_f...           0.874254
# 484  {'bootstrap': False, 'max_depth': None, 'max_f...           0.874254
# 485  {'bootstrap': False, 'max_depth': None, 'max_f...           0.874254
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0             0.875644           0.841398           0.911105
# 1             0.858503           0.841398           0.911105
# 2             0.857143           0.841398           0.911105
# 3             0.858503           0.841398           0.947015
# 4             0.875644           0.859435           0.929144
# ..                 ...                ...                ...
# 481           0.858503           0.877280           0.947015
# 482           0.858503           0.877280           0.964572
# 483           0.858503           0.877280           0.947015
# 484           0.858503           0.877280           0.947015
# 485           0.858503           0.877280           0.947015
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.946153         0.889711        0.035817              410
# 1             0.964286         0.889909        0.043740              386
# 2             0.964286         0.889637        0.043938              415
# 3             0.964286         0.897091        0.049234              310
# 4             0.964286         0.900552        0.039704              306
# ..                 ...              ...             ...              ...
# 481           0.964286         0.904268        0.042786              145
# 482           0.964286         0.907779        0.046692              102
# 483           0.946153         0.900641        0.038051              292
# 484           0.964286         0.904268        0.042786              145
# 485           0.964286         0.904268        0.042786              145
#
# [486 rows x 19 columns]

# %%
age_input=float(input("Age."))
salary_input=float(input("salary:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
# Out:
# Age. 20
# salary: 55
# Sex Male 0 or 1: 1

# %%
grid.predict([[age_input,salary_input,sex_male_input]])
# Out:
# array([1])
