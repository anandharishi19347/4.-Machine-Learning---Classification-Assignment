# %%
#importing the Libraries#
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the Dataset#
dataset=pd.read_csv('Social_Network_Ads.csv')

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#create dummy data set. #drop a column#
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
#catogorical data convert to numerical data#
dataset=dataset.astype(int)

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
#show all columns in dataset#
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
#independent variable means input.  #split input variables. #dataset assigned to independent variable#
independent=dataset[['Age', 'EstimatedSalary','Gender_Male']]

# %%
#what saved in this file#
independent
# Out:
#      Age  EstimatedSalary  Gender_Male
# 0     19            19000            1
# 1     35            20000            1
# 2     26            43000            0
# 3     27            57000            0
# 4     19            76000            1
# ..   ...              ...          ...
# 395   46            41000            0
# 396   51            23000            1
# 397   50            20000            0
# 398   36            33000            1
# 399   49            36000            0
#
# [400 rows x 3 columns]

# %%
#dependent variable means output.  #split output variables. #dataset assigned to dependent variable#
dependent=dataset[['Purchased']]

# %%
#what saved in this file#
dependent
# Out:
#      Purchased
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 395          1
# 396          1
# 397          1
# 398          0
# 399          1
#
# [400 rows x 1 columns]

# %%
#machine learning algorithms provider is sklearn #split train set and test set#
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test=train_test_split(independent, dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Model creation#
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],
              'C':[19,100,1000,2000,3000],'gamma':['auto','scale'] }
grid=GridSearchCV(SVC(probability=True), param_grid, refit=True, verbose=3,n_jobs=-1,scoring='f1_weighted')

#fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [19, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
y_pred = grid.predict(X_test) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)



# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, y_pred)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,y_pred,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}: 0.9161458333333334

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[75  4]
#  [ 6 35]]

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94        79
#            1       0.90      0.85      0.88        41
#
#     accuracy                           0.92       120
#    macro avg       0.91      0.90      0.91       120
# weighted avg       0.92      0.92      0.92       120

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9617165791911083

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.160613      0.082545         0.046713    2.957695e-02      19
# 1        0.149161      0.113441         0.025435    1.144868e-02      19
# 2        0.018756      0.006256         0.020778    6.542233e-03      19
# 3        0.095857      0.014045         0.033707    1.801145e-02      19
# 4        0.072232      0.014591         0.034670    1.798571e-02      19
# 5        0.121499      0.115797         0.024975    1.252276e-02      19
# 6        0.157675      0.187838         0.017132    7.724741e-03      19
# 7        0.130622      0.072757         0.023693    6.758632e-03      19
# 8        0.068839      0.007587         0.034377    1.169388e-02     100
# 9        0.183870      0.056161         0.017815    2.983324e-03     100
# 10       0.056324      0.006333         0.028023    1.270242e-02     100
# 11       0.198366      0.110028         0.025155    1.905668e-02     100
# 12       0.086121      0.018418         0.020621    1.335232e-02     100
# 13       0.249063      0.075750         0.071352    5.388968e-02     100
# 14       0.068699      0.083055         0.021180    1.188727e-02     100
# 15       0.182212      0.042191         0.025716    1.335307e-02     100
# 16       0.143070      0.035605         0.017144    3.003992e-03    1000
# 17       1.255188      0.215908         0.034368    1.530115e-02    1000
# 18       0.076441      0.024281         0.026995    2.273455e-02    1000
# 19       1.025706      0.076490         0.021878    7.654675e-03    1000
# 20       0.188772      0.016772         0.035025    2.378011e-02    1000
# 21       1.512289      0.408023         0.026527    1.955439e-02    1000
# 22       0.093453      0.026633         0.022586    7.199540e-03    1000
# 23       1.494350      0.583219         0.024243    1.229333e-02    1000
# 24       0.303049      0.111203         0.028135    1.822524e-02    2000
# 25       2.560700      0.795084         0.031253    1.711685e-02    2000
# 26       0.065361      0.022642         0.015627    7.325311e-07    2000
# 27       1.963716      0.451433         0.043755    2.296397e-02    2000
# 28       0.275019      0.042623         0.044085    3.051122e-02    2000
# 29       2.516882      0.627672         0.031254    1.976680e-02    2000
# 30       0.070438      0.039007         0.015627    1.302385e-06    2000
# 31       1.703335      0.083311         0.015822    3.875583e-04    2000
# 32       0.337522      0.065255         0.015626    1.319728e-06    3000
# 33       3.153642      0.964009         0.021880    2.119768e-02    3000
# 34       0.053128      0.028982         0.015627    2.437939e-06    3000
# 35       3.496705      1.149130         0.017796    6.981023e-03    3000
# 36       0.443524      0.036491         0.015628    3.006722e-06    3000
# 37       4.047606      2.189443         0.031092    1.963633e-02    3000
# 38       0.050005      0.025002         0.018752    6.250405e-03    3000
# 39       4.599347      1.326030         0.041567    2.699946e-02    3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 19, 'gamma': 'auto', 'kernel': 'rbf'}           0.874254
# 1        {'C': 19, 'gamma': 'auto', 'kernel': 'poly'}           0.833024
# 2     {'C': 19, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.769053
# 3      {'C': 19, 'gamma': 'auto', 'kernel': 'linear'}           0.835985
# 4        {'C': 19, 'gamma': 'scale', 'kernel': 'rbf'}           0.874254
# 5       {'C': 19, 'gamma': 'scale', 'kernel': 'poly'}           0.833024
# 6    {'C': 19, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.769053
# 7     {'C': 19, 'gamma': 'scale', 'kernel': 'linear'}           0.835985
# 8        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.855314
# 9       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.833024
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.769053
# 11    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.835985
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.855314
# 13     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.833024
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.769053
# 15   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.835985
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.835985
# 17     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.833024
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.769053
# 19   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.835985
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.835985
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.833024
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.769053
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.835985
# 24      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.819142
# 25     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.833024
# 26  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.769053
# 27   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.835985
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.819142
# 29    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.833024
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...           0.769053
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.835985
# 32      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.819142
# 33     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.833024
# 34  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.769053
# 35   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.835985
# 36     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.819142
# 37    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.833024
# 38  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...           0.769053
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.835985
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0