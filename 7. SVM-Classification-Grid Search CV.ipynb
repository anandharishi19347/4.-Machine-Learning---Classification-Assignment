# %%
#importing the Libraries#
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the Dataset#
dataset=pd.read_csv('Social_Network_Ads.csv')

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#create dummy data set. #drop a column#
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
#catogorical data convert to numerical data#
dataset=dataset.astype(int)

# %%
#what saved in this file#
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
#show all columns in dataset#
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
#independent variable means input.  #split input variables. #dataset assigned to independent variable#
independent=dataset[['Age', 'EstimatedSalary','Gender_Male']]

# %%
#what saved in this file#
independent
# Out:
#      Age  EstimatedSalary  Gender_Male
# 0     19            19000            1
# 1     35            20000            1
# 2     26            43000            0
# 3     27            57000            0
# 4     19            76000            1
# ..   ...              ...          ...
# 395   46            41000            0
# 396   51            23000            1
# 397   50            20000            0
# 398   36            33000            1
# 399   49            36000            0
#
# [400 rows x 3 columns]

# %%
#dependent variable means output.  #split output variables. #dataset assigned to dependent variable#
dependent=dataset[['Purchased']]

# %%
#what saved in this file#
dependent
# Out:
#      Purchased
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 395          1
# 396          1
# 397          1
# 398          0
# 399          1
#
# [400 rows x 1 columns]

# %%
#machine learning algorithms provider is sklearn #split train set and test set#
from sklearn.model_selection import train_test_split 
X_train,X_test,y_train,y_test=train_test_split(independent, dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Model creation#
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],
              'C':[19,100,1000,2000,3000],'gamma':['auto','scale'] }
grid=GridSearchCV(SVC(probability=True), param_grid, refit=True, verbose=3,n_jobs=-1)

#fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\anandha rishi\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [19, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
y_pred = grid.predict(X_test) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)



# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, y_pred)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,y_pred,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}: 0.9161458333333334

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[75  4]
#  [ 6 35]]

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94        79
#            1       0.90      0.85      0.88        41
#
#     accuracy                           0.92       120
#    macro avg       0.91      0.90      0.91       120
# weighted avg       0.92      0.92      0.92       120

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9617165791911083

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.031488      0.009893         0.013842        0.004012      19
# 1        0.038922      0.009065         0.007676        0.003919      19
# 2        0.024658      0.007013         0.012476        0.007839      19
# 3        0.061364      0.008172         0.013307        0.005522      19
# 4        0.039731      0.005342         0.013104        0.002839      19
# 5        0.035646      0.006371         0.008086        0.003126      19
# 6        0.020630      0.000811         0.008099        0.004049      19
# 7        0.038858      0.006747         0.005257        0.004359      19
# 8        0.032339      0.003180         0.004418        0.003885     100
# 9        0.096088      0.018553         0.006070        0.004243     100
# 10       0.020205      0.000037         0.008502        0.003229     100
# 11       0.110755      0.023961         0.009715        0.000807     100
# 12       0.033576      0.004911         0.006476        0.003694     100
# 13       0.111366      0.042470         0.006071        0.004237     100
# 14       0.021306      0.003354         0.007688        0.002971     100
# 15       0.092355      0.007123         0.007289        0.002737     100
# 16       0.119369      0.028613         0.005385        0.005071    1000
# 17       0.731233      0.218384         0.007346        0.002996    1000
# 18       0.020178      0.000015         0.007685        0.003921    1000
# 19       0.640872      0.179416         0.010396        0.001746    1000
# 20       0.097286      0.027091         0.007269        0.003750    1000
# 21       0.787346      0.396517         0.007569        0.003913    1000
# 22       0.029248      0.007733         0.006477        0.003751    1000
# 23       0.504747      0.109528         0.009789        0.004496    1000
# 24       0.163615      0.044511         0.012989        0.003171    2000
# 25       1.503191      0.241066         0.007169        0.003062    2000
# 26       0.020753      0.003237         0.005260        0.004151    2000
# 27       1.098193      0.128671         0.003646        0.003230    2000
# 28       0.139680      0.027487         0.010580        0.006460    2000
# 29       1.448678      0.551248         0.007829        0.003976    2000
# 30       0.018803      0.003369         0.008610        0.004427    2000
# 31       1.099123      0.070387         0.008096        0.004048    2000
# 32       0.167931      0.025972         0.006055        0.004229    3000
# 33       2.132478      0.587281         0.010100        0.000059    3000
# 34       0.016490      0.003615         0.006441        0.003678    3000
# 35       2.228432      0.956920         0.006043        0.004224    3000
# 36       0.187421      0.024150         0.006845        0.003515    3000
# 37       1.904804      0.617141         0.006969        0.006517    3000
# 38       0.023107      0.004112         0.006811        0.004809    3000
# 39       1.839418      0.556708         0.007983        0.005262    3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 19, 'gamma': 'auto', 'kernel': 'rbf'}           0.875000
# 1        {'C': 19, 'gamma': 'auto', 'kernel': 'poly'}           0.839286
# 2     {'C': 19, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.767857
# 3      {'C': 19, 'gamma': 'auto', 'kernel': 'linear'}           0.839286
# 4        {'C': 19, 'gamma': 'scale', 'kernel': 'rbf'}           0.875000
# 5       {'C': 19, 'gamma': 'scale', 'kernel': 'poly'}           0.839286
# 6    {'C': 19, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.767857
# 7     {'C': 19, 'gamma': 'scale', 'kernel': 'linear'}           0.839286
# 8        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.857143
# 9       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.839286
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.767857
# 11    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.839286
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.857143
# 13     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.839286
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.767857
# 15   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.839286
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.839286
# 17     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.839286
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.767857
# 19   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.839286
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.839286
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.839286
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.767857
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.839286
# 24      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.821429
# 25     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.839286
# 26  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.767857
# 27   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.839286
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.821429
# 29    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.839286
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...           0.767857
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.839286
# 32      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.821429
# 33     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.839286
# 34  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.767857
# 35   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.839286
# 36     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.821429
# 37    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.839286
# 38  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...           0.767857
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.839286
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0